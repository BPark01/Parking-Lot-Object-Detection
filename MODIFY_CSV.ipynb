# %%
import pandas as pd
data_df = pd.read_csv('all_data_drop_na.csv')

# %%
data_df
# Out:
#         Unnamed: 0                filename  center_x  center_y  width  height  \
# 0                0   2012-09-11_15_16_58_1       300       207     55      32
# 1                1   2012-09-11_15_16_58_2       332       209     56      33
# 2                2   2012-09-11_15_16_58_3       366       208     52      32
# 3                3   2012-09-11_15_16_58_4       398       207     54      36
# 4                4   2012-09-11_15_16_58_5       430       210     50      31
# ...            ...                     ...       ...       ...    ...     ...
# 694123      719523  2013-04-16_10_50_05_36       817        62     41      78
# 694124      719524  2013-04-16_10_50_05_37       776        31     41      88
# 694125      719525  2013-04-16_10_50_05_38      1152       118     58      69
# 694126      719526  2013-04-16_10_50_05_39      1087        84     61      57
# 694127      719527  2013-04-16_10_50_05_40      1031        57     55      58
#
# ...

# %%
len(data_df)
# Out:
# 694128

# %%
print(data_df.iloc[0,8])
print(data_df.iloc[0,9])
print(data_df.iloc[0,10])
print(data_df.iloc[0,11])
# Out:
# 324
# 278
# 230
# 185

# %%
cnt = 0
for i in range(len(data_df)):
    data =  data_df.iloc[i]
    x_max = data.x_max.copy()
    x_min = data.x_min.copy()
    y_max = data.y_max.copy()
    y_min = data.y_min.copy()
    if data.x_max < data.x_min:
        data_df.iloc[i,8] = x_min
        data_df.iloc[i,9] = x_max
        cnt += 0.5
    if data.y_max < data.y_min:
        data_df.iloc[i,10] = y_min
        data_df.iloc[i,11] = y_max
        cnt += 0.5
print(cnt)
# Out:
# 40494.0

# %%
data_df
# Out:
#         Unnamed: 0                filename  center_x  center_y  width  height  \
# 0                0   2012-09-11_15_16_58_1       300       207     55      32
# 1                1   2012-09-11_15_16_58_2       332       209     56      33
# 2                2   2012-09-11_15_16_58_3       366       208     52      32
# 3                3   2012-09-11_15_16_58_4       398       207     54      36
# 4                4   2012-09-11_15_16_58_5       430       210     50      31
# ...            ...                     ...       ...       ...    ...     ...
# 694123      719523  2013-04-16_10_50_05_36       817        62     41      78
# 694124      719524  2013-04-16_10_50_05_37       776        31     41      88
# 694125      719525  2013-04-16_10_50_05_38      1152       118     58      69
# 694126      719526  2013-04-16_10_50_05_39      1087        84     61      57
# 694127      719527  2013-04-16_10_50_05_40      1031        57     55      58
#
# ...

# %%
data_df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
data_df
# Out:
#                       filename  center_x  center_y  width  height  angle  \
# 0        2012-09-11_15_16_58_1       300       207     55      32    -74
# 1        2012-09-11_15_16_58_2       332       209     56      33    -77
# 2        2012-09-11_15_16_58_3       366       208     52      32    -77
# 3        2012-09-11_15_16_58_4       398       207     54      36    -79
# 4        2012-09-11_15_16_58_5       430       210     50      31    -75
# ...                        ...       ...       ...    ...     ...    ...
# 694123  2013-04-16_10_50_05_36       817        62     41      78    -88
# 694124  2013-04-16_10_50_05_37       776        31     41      88    -88
# 694125  2013-04-16_10_50_05_38      1152       118     58      69      0
# 694126  2013-04-16_10_50_05_39      1087        84     61      57      0
# 694127  2013-04-16_10_50_05_40      1031        57     55      58    -83
#
#         occupied  x_max  x_min  y_max  y_min
# 0            1.0    324    278    230    185
# ...

# %%
data_df.to_csv("modi_xml.csv")

# %%
data_df['occupied'].value_counts()
# Out:
# 0.0    358742
# 1.0    335386
# Name: occupied, dtype: int64
